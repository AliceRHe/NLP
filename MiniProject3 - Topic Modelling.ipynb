# %%
# Import Libraries
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import jaxlib
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

# %% [markdown]
# # Topic Modelling
#
# - create a topic modelling to sort through the reviews to get an exact topic

# %%
raw_df = pd.read_csv('dog_supplement_no_na.csv')
raw_df.head()
# Out:
#                      name        date                               title  \
# 0                  Blayne  2023-02-17                        please avoid
# 1           Jake Morrison  2023-02-17           dog was allergic to these
# 2  le’MamaAmazon Customer  2021-02-01              these made my dog sick
# 3                 Captain  2023-03-04  12 yo italian grey hound very sick
# 4                   Dio I  2022-05-28                   not for every dog
#
#    rating                                             review         country  \
# 0     1.0  you try to do right by your dog by getting the...  United States
# 1     1.0  i have an 80lb weimaraner and started him off ...  United States
# 2     1.0  poor little guy apparently i have one of those...  United States
# 3     1.0  i have two dogs and my boxer mix doesnt seem t...  United States
# 4     1.0  i wanted to take my time before i write this n...  United States
#
#   sentiment
# 0  negative
# 1  negative
# 2  negative
# 3  negative
# 4  negative

# %%
raw_df.isna().sum()
# Out:
# name         0
# date         0
# title        0
# rating       0
# review       0
# country      0
# sentiment    0
# dtype: int64

# %%
# concatenate the review and title into a single column
raw_df['total_text'] = raw_df['title'] + ' ' + raw_df['review']

# %%
# check df
raw_df.head()
# Out:
#                      name        date                               title  \
# 0                  Blayne  2023-02-17                        please avoid
# 1           Jake Morrison  2023-02-17           dog was allergic to these
# 2  le’MamaAmazon Customer  2021-02-01              these made my dog sick
# 3                 Captain  2023-03-04  12 yo italian grey hound very sick
# 4                   Dio I  2022-05-28                   not for every dog
#
#    rating                                             review         country  \
# 0     1.0  you try to do right by your dog by getting the...  United States
# 1     1.0  i have an 80lb weimaraner and started him off ...  United States
# 2     1.0  poor little guy apparently i have one of those...  United States
# 3     1.0  i have two dogs and my boxer mix doesnt seem t...  United States
# 4     1.0  i wanted to take my time before i write this n...  United States
#
#   sentiment                                         total_text
# 0  negative  please avoid you try to do right by your dog b...
# 1  negative  dog was allergic to these i have an 80lb weima...
# 2  negative  these made my dog sick poor little guy apparen...
# 3  negative  12 yo italian grey hound very sick i have two ...
# 4  negative  not for every dog i wanted to take my time bef...

# %%
# dropping some rows that don't give additional information
raw_df = raw_df.drop(columns=['name', 'date', 'country'])
raw_df.head()
# Out:
#                                 title  rating  \
# 0                        please avoid     1.0
# 1           dog was allergic to these     1.0
# 2              these made my dog sick     1.0
# 3  12 yo italian grey hound very sick     1.0
# 4                   not for every dog     1.0
#
#                                               review sentiment  \
# 0  you try to do right by your dog by getting the...  negative
# 1  i have an 80lb weimaraner and started him off ...  negative
# 2  poor little guy apparently i have one of those...  negative
# 3  i have two dogs and my boxer mix doesnt seem t...  negative
# 4  i wanted to take my time before i write this n...  negative
#
#                                           total_text
# 0  please avoid you try to do right by your dog b...
# 1  dog was allergic to these i have an 80lb weima...
# 2  these made my dog sick poor little guy apparen...
# 3  12 yo italian grey hound very sick i have two ...
# 4  not for every dog i wanted to take my time bef...

# %%
# create samples with a balanced dataset
# Select 20 negative samples
negative_df = raw_df[raw_df['sentiment'] == 'negative'].sample(20)

# Select 30 positive samples
positive_df = raw_df[raw_df['sentiment'] == 'positive'].sample(30)

# Concatenate the two subsets
pred_df = pd.concat([negative_df, positive_df])
pred_df.head()
# Out:
#                                   title  rating  \
# 352  my dog keeps on throwing it all up     1.0
# 520               dont buy this product     1.0
# 841                   dogs dont like it     2.0
# 869                  dogs would not eat     2.0
# 964                      not a good buy     2.0
#
#                                                 review sentiment  \
# 352  so ive started giving a small dosage less than...  negative
# 520  this product made my dogs very sick and almost...  negative
# 841  the vision bites are perfect but the dogs 2 di...  negative
# 869  no idea if these will work or not  the dogs re...  negative
# 964                                   made my dog sick  negative
#
#                                             total_text
# 352  my dog keeps on throwing it all up so ive star...
# 520  dont buy this product this product made my dog...
# 841  dogs dont like it the vision bites are perfect...
# 869  dogs would not eat no idea if these will work ...
# 964                    not a good buy made my dog sick

# %%
# topic modelling using pipeline
clf = pipeline('zero-shot-classification', model='facebook/bart-large-mnli', tokenizer='facebook/bart-large-mnli')

# some positive and negative topics chosen from WordCloud and some concern topics
candidate_labels = [
    'good product',
    'bad product', 
    'highly recommended',
    'concern: joint', 
    'concern: skin',
    'concern: coat',
    'concern: heart',
    'concern: gut',
    'concern: liver',
    'made dog sick',
    'vomited',
    'returned product',
    'diarrhea',
    'allergic to product'
]

# applying to sample df
pred_df['prediction'] = pred_df['total_text'].apply(lambda x: clf(x, candidate_labels)['labels'][0])

# %%
# reset the index
pred_df = pred_df.reset_index()

# drop index row
pred_df = pred_df.drop(columns='index')

# %%
# check topics
pred_df
# Out:
#                                                 title  rating  \
# 0                  my dog keeps on throwing it all up     1.0
# 1                               dont buy this product     1.0
# 2                                   dogs dont like it     2.0
# 3                                  dogs would not eat     2.0
# 4                                      not a good buy     2.0
# 5                                            bad idea     1.0
# 6       product seemed to be old smelled and crumbled     1.0
# 7                                       would not eat     1.0
# 8                                        i would pass     2.0
# 9                               dogs didnt like taste     2.0
# 10                        my dog will not even eat it     1.0
# 11                 really messed my dogs digestion up     2.0
# 12                                theyre okay i guess     2.0
# 13                              didnt work for my pup     1.0
# 14               same bad reaction as other reviewers     1.0
# 15                                  dog gone disaster     1.0
# 16                                             8 on 1     2.0
# 17                        it made one of my dogs sick     1.0
# 18  not worth it dog refuses to eat it waste of money     1.0
# 19                                        sick german     1.0
# 20                                 my dog loves these     5.0
# 21                           i give it to all my dogs     5.0
# 22                                 my dog loves these     5.0
# 23                               vitamins are amazing     5.0
# 24                         they think they are treats     5.0
# 25  highly highly recommended best vitamins i foun...     5.0
# 26                                 my kids love these     5.0
# 27                                my dogs love those      5.0
# 28  our older dog is able to move around and is pl...     5.0
# 29                       great for my 12 year old dog     5.0
# 30                     my boy thinks these are delish     5.0
# 31                                  zesty paws treats     5.0
# 32             excellent product and customer service     5.0
# 33                                    it really works     5.0
# 34       really helped our 7 year old standard poodle     5.0
# 35                         paws up for these vitamins     5.0
# 36     excellent product havent found anything better     5.0
# 37                          my senior pups love them      5.0
# 38                everything my dogs need in one pill     5.0
# 39                 5 in 1 multivitamin bites for dogs     5.0
# 40                      used it as a treat for my dog     5.0
# 41                        great for even picky eaters     5.0
# 42                 pups love  they are great for them     5.0
# 43                                   works all around     5.0
# 44                      daily supplements have helped     5.0
# 45                                amazing supplements     5.0
# 46                                       healthy dogs     5.0
# 47                  im not a doctor or a nutritionist     5.0
# 48                                     pet loves them     5.0
# 49                                      he loves them     5.0
#
#                                                review sentiment  \
# 0   so ive started giving a small dosage less than...  negative
# 1   this product made my dogs very sick and almost...  negative
# 2   the vision bites are perfect but the dogs 2 di...  negative
# 3   no idea if these will work or not  the dogs re...  negative
# 4                                    made my dog sick  negative
# 5   i bought this for our dog molly who is turning...  negative
# 6   the product smelled bad my dog would not even ...  negative
# 7   my puppy disliked tryed mixing with other food...  negative
# 8               didnt do much make my dogs poop loose  negative
# 9                       dogs were reluctant to eat it  negative
# 10  was so excited to try these for my 12 year old...  negative
# 11  i tried to persist and started with just one t...  negative
# 12  im initially extremely put off by the coloring...  negative
# 13  unfortunately this product didnt have any effe...  negative
# 14  a week into taking them my little dog started ...  negative
# 15  my dog had diarrhea after taking which left a ...  negative
# 16               for some reason the dogs do not like  negative
# 17  i read a lot of the reviews before purchasing ...  negative
# 18  dog wont eat it at all just keeps spitting it ...  negative
# 19         our dog is lifeless thanks to this garbage  negative
# 20  i bought these for my 6 month old puppy i have...  positive
# 21  im not sure if and when this should be helpful...  positive
# 22  at first my dog was a little hesitant of the t...  positive
# 23  i do like them and i have been giving them to ...  positive
# 24  this is to review the multi vitamin 8 in 1 for...  positive
# 25  i cannot tell u enough just how amazing these ...  positive
# 26  my little fur babies think these are one of th...  positive
# 27  i cook for my 2 dogs i need to add multivitami...  positive
# 28  i bought this product to help our older dog wi...  positive
# 29  been giving these to my 12 year old dog on a d...  positive
# 30  we have two dogs one who is a senior who gets ...  positive
# 31  my toy poodle loves them we do the allerimmune...  positive
# 32  update customer service reached out to me and ...  positive
# 33  we tried this supplement because our old dog c...  positive
# 34  we were so relieved to find a product that hel...  positive
# 35  my dogs love these i have one picky eater who ...  positive
# 36  i havent found anything better for my dog my p...  positive
# 37  great quality supplement for my two senior pup...  positive
# 38  i have an 8 yr old westie she seemed to be slo...  positive
# 39  my little pug has pain in her backive tried it...  positive
# 40  my dog is really picky but he really liked the...  positive
# 41  i have 3 dogs two of which are incredibly pick...  positive
# 42  my pups love these supplements  think they are...  positive
# 43  my dogs love these treats and seem to be much ...  positive
# 44  our 13yearold labradoodle has one of these eve...  positive
# 45  we have a 10year old boxer who was suffering f...  positive
# 46  my dogs love these take them like treats and s...  positive
